# %%
import pandas as pd
import json

# %%
with open('../levelsFYI_crawler/data/levelsFYI.json', 'r') as f:
    data = json.loads(f.read())

data = pd.json_normalize(data, max_level=1)

# %%
def raceFunc(s):
    if s is None:return 'null'
    try:
        if 'Race' in s: 
            return s.split('Race: ', 1)[1].split(',')[0]
    except:
        return 'null'

# %%
def acaFunc(s):
    if s is None: return 'null'
    if 'Academic Level' in s: 
        if 'Bachelor' in s: return 'Bachelor'
        elif 'Master' in s: return 'Master'
        else:
            return s.split('Academic Level: ', 1)[1].split(',')[0]

# %%
def remoteFunc(s):
    if s is None: return 'no'
    if 'Remote' in s: return 'yes'

# %%
data['Remote'] = data['otherdetails'].apply(remoteFunc)
data['Academic Level'] = data['otherdetails'].apply(acaFunc)
data['Race'] = data['otherdetails'].apply(raceFunc)

# %%
data
# Out:
#                                        uuid                 timestamp  \
# 0      0fcb8359-2ab8-55ce-bab0-1fe6443dded1  2021-10-25T09:45:07.000Z
# 1      fa1b1f73-3ddd-5abc-8bbb-f3ee6a481ff1  2021-10-25T09:36:13.000Z
# 2      67348483-2f0d-5212-a72a-810a55860c05  2021-10-25T09:06:18.000Z
# 3      c5118f1e-9553-5ba3-97e9-4e311962fdef  2021-10-25T08:33:10.000Z
# 4      42f0fe99-bace-505b-9e69-dc3c47bdafc6  2021-10-25T07:50:19.000Z
# ...                                     ...                       ...
# 47945  03b0b7f5-8658-5617-b67f-76b9e452df15  2017-06-22T00:27:47.000Z
# 47946  e4e00561-dcef-53af-8fb8-b6393cf1b087  2017-06-21T01:49:59.000Z
# 47947  e04911e6-1ba8-5563-ba38-9e8308fd06db  2017-06-20T17:58:51.000Z
# 47948  af0b4a52-f513-5525-b746-37c788f4d534  2017-06-16T17:44:01.000Z
# 47949  cb1a4aa8-fcf9-5700-85ac-74d0843abdc0  2017-06-11T00:11:29.000Z
#
#          level              title  totalyearlycompensation  \
# 0       Senior  Software Engineer                   4400.0
# 1       SDE II  Software Engineer                     48.0
# 2           28  Software Engineer                     93.0
# 3      Analyst  Software Engineer                     49.0
# 4         IC-3  Software Engineer                    350.0
# ...        ...                ...                      ...
# 47945       63  Software Engineer                    208.0
# 47946       L5  Software Engineer                    190.0
# 47947       60  Software Engineer                    157.0
# 47948       L5  Software Engineer                    173.0
# 47949     SE 2  Software Engineer                    100.0
#
#                     location  yearsofexperience  yearsatcompany  \
# 0       Bengaluru, KA, India                6.0             1.0
# 1         Moscow, MC, Russia                5.0             0.0
# 2        Dublin, DN, Ireland                5.0             3.0
# 3       Bengaluru, KA, India                0.0             0.0
# 4                Seattle, WA                5.0             2.0
# ...                      ...                ...             ...
# 47945            Seattle, WA                8.5             8.5
# 47946            Seattle, WA                3.0             3.0
# 47947      Mountain View, CA                5.0             3.0
# 47948  Vancouver, BC, Canada               11.0             1.0
# 47949      San Francisco, CA                5.0             3.0
#
#                                   tag  basesalary  ...  gender  \
# 0         Web Development (Front-End)      3700.0  ...    None
# 1      Distributed Systems (Back-End)        43.0  ...    male
# 2                                 Rps        90.0  ...  female
# 3               Quantitative Engineer        32.0  ...    male
# 4      Distributed Systems (Back-End)       165.0  ...    None
# ...                               ...         ...  ...     ...
# 47945                            None         NaN  ...    None
# 47946                            None    110000.0  ...    None
# 47947                            None         NaN  ...    None
# 47948                            None    120000.0  ...    None
# 47949                            None         NaN  ...    None
#
#                                             otherdetails cityid  dmaid  \
# 0                        Title: Senior Software Engineer  42498    0.0
# 1      Title: Software Engineer, Race: White, Academi...   1384    0.0
# 2      Title: Senior Software Engineer, Race: White, ...   4015    0.0
# 3      Around $10k out of $16k is joining bonus for f...  42498    0.0
# 4                Title: Senior Member Of Technical Staff  11527  819.0
# ...                                                  ...    ...    ...
# 47945                                               None  11527  819.0
# 47946                                               None  11527  819.0
# 47947                                               None   7322  807.0
# 47948                                               None   1320    0.0
# 47949                                               None   7419  807.0
#
#         company.name                                company.icon  \
# 0          Unacademy     https://logo.clearbit.com/unacademy.com
# 1       Tinkoff Bank  https://logo.clearbit.com/tinkoffgroup.com
# 2              Optum         https://logo.clearbit.com/optum.com
# 3      Goldman Sachs  https://logo.clearbit.com/goldmansachs.com
# 4             Oracle        https://logo.clearbit.com/oracle.com
# ...              ...                                         ...
# 47945      Microsoft     https://logo.clearbit.com/microsoft.com
# 47946         Amazon        https://logo.clearbit.com/amazon.com
# 47947      Microsoft     https://logo.clearbit.com/microsoft.com
# 47948         Amazon        https://logo.clearbit.com/amazon.com
# 47949           eBay          https://logo.clearbit.com/ebay.com
#
#       company.registered Remote  Academic Level   Race
# 0                   True   None            None   None
# 1                   True   None          Master  White
# 2                   True   None        Bachelor  White
# 3                   True   None          Master  Asian
# 4                   True   None            None   None
# ...                  ...    ...             ...    ...
# 47945               True     no            null   null
# 47946               True     no            null   null
# 47947               True     no            null   null
# 47948               True     no            null   null
# 47949               True     no            null   null
#
# [47950 rows x 22 columns]

# %%
data = data.drop(['uuid','title','otherdetails','cityid','dmaid'], axis=1)

# %%
data
# Out:
#                       timestamp    level  totalyearlycompensation  \
# 0      2021-10-25T09:45:07.000Z   Senior                   4400.0
# 1      2021-10-25T09:36:13.000Z   SDE II                     48.0
# 2      2021-10-25T09:06:18.000Z       28                     93.0
# 3      2021-10-25T08:33:10.000Z  Analyst                     49.0
# 4      2021-10-25T07:50:19.000Z     IC-3                    350.0
# ...                         ...      ...                      ...
# 47945  2017-06-22T00:27:47.000Z       63                    208.0
# 47946  2017-06-21T01:49:59.000Z       L5                    190.0
# 47947  2017-06-20T17:58:51.000Z       60                    157.0
# 47948  2017-06-16T17:44:01.000Z       L5                    173.0
# 47949  2017-06-11T00:11:29.000Z     SE 2                    100.0
#
#                     location  yearsofexperience  yearsatcompany  \
# 0       Bengaluru, KA, India                6.0             1.0
# 1         Moscow, MC, Russia                5.0             0.0
# 2        Dublin, DN, Ireland                5.0             3.0
# 3       Bengaluru, KA, India                0.0             0.0
# 4                Seattle, WA                5.0             2.0
# ...                      ...                ...             ...
# 47945            Seattle, WA                8.5             8.5
# 47946            Seattle, WA                3.0             3.0
# 47947      Mountain View, CA                5.0             3.0
# 47948  Vancouver, BC, Canada               11.0             1.0
# 47949      San Francisco, CA                5.0             3.0
#
#                                   tag  basesalary  stockgrantvalue    bonus  \
# 0         Web Development (Front-End)      3700.0            500.0    200.0
# 1      Distributed Systems (Back-End)        43.0              0.0      5.0
# 2                                 Rps        90.0              0.0      3.0
# 3               Quantitative Engineer        32.0              0.0     17.0
# 4      Distributed Systems (Back-End)       165.0            175.0     10.0
# ...                               ...         ...              ...      ...
# 47945                            None         NaN              NaN      NaN
# 47946                            None    110000.0          80000.0      NaN
# 47947                            None         NaN              NaN      NaN
# 47948                            None    120000.0              0.0  53000.0
# 47949                            None         NaN              NaN      NaN
#
#        gender   company.name                                company.icon  \
# 0        None      Unacademy     https://logo.clearbit.com/unacademy.com
# 1        male   Tinkoff Bank  https://logo.clearbit.com/tinkoffgroup.com
# 2      female          Optum         https://logo.clearbit.com/optum.com
# 3        male  Goldman Sachs  https://logo.clearbit.com/goldmansachs.com
# 4        None         Oracle        https://logo.clearbit.com/oracle.com
# ...       ...            ...                                         ...
# 47945    None      Microsoft     https://logo.clearbit.com/microsoft.com
# 47946    None         Amazon        https://logo.clearbit.com/amazon.com
# 47947    None      Microsoft     https://logo.clearbit.com/microsoft.com
# 47948    None         Amazon        https://logo.clearbit.com/amazon.com
# 47949    None           eBay          https://logo.clearbit.com/ebay.com
#
#        company.registered Remote Academic Level   Race
# 0                    True   None           None   None
# 1                    True   None         Master  White
# 2                    True   None       Bachelor  White
# 3                    True   None         Master  Asian
# 4                    True   None           None   None
# ...                   ...    ...            ...    ...
# 47945                True     no           null   null
# 47946                True     no           null   null
# 47947                True     no           null   null
# 47948                True     no           null   null
# 47949                True     no           null   null
#
# [47950 rows x 17 columns]

# %%
data.to_csv('data.csv', header=False, index=False)

# %%
data = data.to_dict(orient='records')

# %%
data
# Out:
# [{'timestamp': '2021-10-25T09:45:07.000Z',
#   'level': 'Senior',
#   'totalyearlycompensation': 4400.0,
#   'location': 'Bengaluru, KA, India',
#   'yearsofexperience': 6.0,
#   'yearsatcompany': 1.0,
#   'tag': 'Web Development (Front-End)',
#   'basesalary': 3700.0,
#   'stockgrantvalue': 500.0,
#   'bonus': 200.0,
#   'gender': None,
#   'company.name': 'Unacademy',
#   'company.icon': 'https://logo.clearbit.com/unacademy.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-25T09:36:13.000Z',
#   'level': 'SDE II',
#   'totalyearlycompensation': 48.0,
#   'location': 'Moscow, MC, Russia',
#   'yearsofexperience': 5.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 43.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 5.0,
#   'gender': 'male',
#   'company.name': 'Tinkoff Bank',
#   'company.icon': 'https://logo.clearbit.com/tinkoffgroup.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'White'},
#  {'timestamp': '2021-10-25T09:06:18.000Z',
#   'level': '28',
#   'totalyearlycompensation': 93.0,
#   'location': 'Dublin, DN, Ireland',
#   'yearsofexperience': 5.0,
#   'yearsatcompany': 3.0,
#   'tag': 'Rps',
#   'basesalary': 90.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 3.0,
#   'gender': 'female',
#   'company.name': 'Optum',
#   'company.icon': 'https://logo.clearbit.com/optum.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'White'},
#  {'timestamp': '2021-10-25T08:33:10.000Z',
#   'level': 'Analyst',
#   'totalyearlycompensation': 49.0,
#   'location': 'Bengaluru, KA, India',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Quantitative Engineer',
#   'basesalary': 32.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 17.0,
#   'gender': 'male',
#   'company.name': 'Goldman Sachs',
#   'company.icon': 'https://logo.clearbit.com/goldmansachs.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-25T07:50:19.000Z',
#   'level': 'IC-3',
#   'totalyearlycompensation': 350.0,
#   'location': 'Seattle, WA',
#   'yearsofexperience': 5.0,
#   'yearsatcompany': 2.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 165.0,
#   'stockgrantvalue': 175.0,
#   'bonus': 10.0,
#   'gender': None,
#   'company.name': 'Oracle',
#   'company.icon': 'https://logo.clearbit.com/oracle.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-25T07:03:53.000Z',
#   'level': 'L2',
#   'totalyearlycompensation': 88.0,
#   'location': 'Phoenix, AZ',
#   'yearsofexperience': 1.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Data',
#   'basesalary': 80.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 8.0,
#   'gender': None,
#   'company.name': 'American Airlines',
#   'company.icon': 'https://logo.clearbit.com/aa.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': None},
#  {'timestamp': '2021-10-25T07:03:03.000Z',
#   'level': 'P1',
#   'totalyearlycompensation': 120.0,
#   'location': 'Reno, NV',
#   'yearsofexperience': 1.0,
#   'yearsatcompany': 1.0,
#   'tag': 'Full Stack',
#   'basesalary': 90.0,
#   'stockgrantvalue': 30.0,
#   'bonus': 0.0,
#   'gender': 'male',
#   'company.name': 'Tesla',
#   'company.icon': 'https://logo.clearbit.com/tesla.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-25T06:54:48.000Z',
#   'level': 'Associate Director',
#   'totalyearlycompensation': 300.0,
#   'location': 'San Francisco, CA',
#   'yearsofexperience': 10.0,
#   'yearsatcompany': 2.0,
#   'tag': 'ML / AI',
#   'basesalary': 295.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 5.0,
#   'gender': None,
#   'company.name': 'Ernst and Young',
#   'company.icon': 'https://logo.clearbit.com/ey.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-25T06:40:57.000Z',
#   'level': 'G16',
#   'totalyearlycompensation': 69.0,
#   'location': 'Moscow, MC, Russia',
#   'yearsofexperience': 5.0,
#   'yearsatcompany': 3.0,
#   'tag': 'Full Stack',
#   'basesalary': 42.0,
#   'stockgrantvalue': 8.0,
#   'bonus': 19.0,
#   'gender': 'male',
#   'company.name': 'Yandex',
#   'company.icon': 'https://logo.clearbit.com/yandex.ru',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'White'},
#  {'timestamp': '2021-10-25T06:21:23.000Z',
#   'level': 'Band 8',
#   'totalyearlycompensation': 145.0,
#   'location': 'Austin, TX',
#   'yearsofexperience': 5.0,
#   'yearsatcompany': 3.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 145.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 0.0,
#   'gender': 'male',
#   'company.name': 'IBM',
#   'company.icon': 'https://logo.clearbit.com/ibm.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-25T06:01:33.000Z',
#   'level': 'Staff Software Engineer',
#   'totalyearlycompensation': 318.0,
#   'location': 'San Jose, CA',
#   'yearsofexperience': 11.0,
#   'yearsatcompany': 3.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 180.0,
#   'stockgrantvalue': 120.0,
#   'bonus': 18.0,
#   'gender': None,
#   'company.name': 'Okta',
#   'company.icon': 'https://logo.clearbit.com/okta.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-25T06:00:18.000Z',
#   'level': 'L1',
#   'totalyearlycompensation': 88.0,
#   'location': 'Minneapolis, MN',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 80.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 8.0,
#   'gender': 'male',
#   'company.name': 'Jamf',
#   'company.icon': 'https://logo.clearbit.com/jamf.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-25T05:56:07.000Z',
#   'level': 'L5',
#   'totalyearlycompensation': 400.0,
#   'location': 'Kirkland, WA',
#   'yearsofexperience': 7.0,
#   'yearsatcompany': 2.0,
#   'tag': 'API Development (Back-End)',
#   'basesalary': 165.0,
#   'stockgrantvalue': 200.0,
#   'bonus': 35.0,
#   'gender': 'male',
#   'company.name': 'Google',
#   'company.icon': 'https://logo.clearbit.com/google.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-25T05:38:51.000Z',
#   'level': '59',
#   'totalyearlycompensation': 154.0,
#   'location': 'Redmond, WA',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Full Stack',
#   'basesalary': 112.0,
#   'stockgrantvalue': 30.0,
#   'bonus': 12.0,
#   'gender': None,
#   'company.name': 'Microsoft',
#   'company.icon': 'https://logo.clearbit.com/microsoft.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-25T05:24:06.000Z',
#   'level': 'Associate MTS',
#   'totalyearlycompensation': 142.0,
#   'location': 'San Francisco, CA',
#   'yearsofexperience': 2.0,
#   'yearsatcompany': 0.0,
#   'tag': 'API Development (Back-End)',
#   'basesalary': 120.0,
#   'stockgrantvalue': 10.0,
#   'bonus': 12.0,
#   'gender': 'male',
#   'company.name': 'Salesforce',
#   'company.icon': 'https://logo.clearbit.com/salesforce.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'White'},
#  {'timestamp': '2021-10-25T05:23:40.000Z',
#   'level': '60',
#   'totalyearlycompensation': 144.0,
#   'location': 'Seattle, WA',
#   'yearsofexperience': 5.0,
#   'yearsatcompany': 1.0,
#   'tag': 'Data',
#   'basesalary': 123.0,
#   'stockgrantvalue': 7.0,
#   'bonus': 14.0,
#   'gender': 'male',
#   'company.name': 'Microsoft',
#   'company.icon': 'https://logo.clearbit.com/microsoft.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-25T05:23:22.000Z',
#   'level': 'L5A',
#   'totalyearlycompensation': 450.0,
#   'location': 'San Francisco, CA',
#   'yearsofexperience': 7.0,
#   'yearsatcompany': 5.0,
#   'tag': 'Android',
#   'basesalary': 190.0,
#   'stockgrantvalue': 225.0,
#   'bonus': 35.0,
#   'gender': None,
#   'company.name': 'Uber',
#   'company.icon': 'https://logo.clearbit.com/uber.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-25T04:58:45.000Z',
#   'level': 'Associate Software Engineer',
#   'totalyearlycompensation': 140.0,
#   'location': 'New York, NY',
#   'yearsofexperience': 2.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 125.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 15.0,
#   'gender': 'male',
#   'company.name': 'JPMorgan Chase',
#   'company.icon': 'https://logo.clearbit.com/jpmorganchase.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Hispanic / Latino'},
#  {'timestamp': '2021-10-25T03:46:56.000Z',
#   'level': 'L5',
#   'totalyearlycompensation': 53.0,
#   'location': 'Bengaluru, KA, India',
#   'yearsofexperience': 10.0,
#   'yearsatcompany': 8.0,
#   'tag': 'DevOps',
#   'basesalary': 47.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 7.0,
#   'gender': 'male',
#   'company.name': 'Informatica',
#   'company.icon': 'https://logo.clearbit.com/informatica.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Two or More Races'},
#  {'timestamp': '2021-10-25T03:32:53.000Z',
#   'level': 'L1',
#   'totalyearlycompensation': 115.0,
#   'location': 'Arlington, VA',
#   'yearsofexperience': 3.0,
#   'yearsatcompany': 3.0,
#   'tag': 'Full Stack',
#   'basesalary': 105.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 10.0,
#   'gender': 'male',
#   'company.name': 'Leidos',
#   'company.icon': 'https://logo.clearbit.com/leidos.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': None},
#  {'timestamp': '2021-10-25T03:23:55.000Z',
#   'level': 'L4',
#   'totalyearlycompensation': 190.0,
#   'location': 'West McLean, VA',
#   'yearsofexperience': 16.0,
#   'yearsatcompany': 1.0,
#   'tag': 'Full Stack',
#   'basesalary': 175.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 15.0,
#   'gender': None,
#   'company.name': 'Freddie Mac',
#   'company.icon': 'https://logo.clearbit.com/freddiemac.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-25T03:05:51.000Z',
#   'level': 'L1',
#   'totalyearlycompensation': 420.0,
#   'location': 'New York, NY',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Full Stack',
#   'basesalary': 200.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 220.0,
#   'gender': None,
#   'company.name': 'Hudson River Trading',
#   'company.icon': 'https://logo.clearbit.com/hudsonrivertrading.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-25T02:54:37.000Z',
#   'level': 'L6',
#   'totalyearlycompensation': 370.0,
#   'location': 'San Francisco, CA',
#   'yearsofexperience': 31.0,
#   'yearsatcompany': 1.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 200.0,
#   'stockgrantvalue': 140.0,
#   'bonus': 30.0,
#   'gender': 'male',
#   'company.name': 'CrowdStrike',
#   'company.icon': 'https://logo.clearbit.com/crowdstrike.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-25T02:47:21.000Z',
#   'level': 'L4',
#   'totalyearlycompensation': 90.0,
#   'location': 'Taipei, TP, Taiwan',
#   'yearsofexperience': 10.0,
#   'yearsatcompany': 3.0,
#   'tag': 'Full Stack',
#   'basesalary': 75.0,
#   'stockgrantvalue': 15.0,
#   'bonus': 0.0,
#   'gender': 'male',
#   'company.name': 'Appier',
#   'company.icon': 'https://logo.clearbit.com/appier.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-25T02:33:42.000Z',
#   'level': 'L1',
#   'totalyearlycompensation': 10.0,
#   'location': 'Ahmedabad, GJ, India',
#   'yearsofexperience': 5.0,
#   'yearsatcompany': 5.0,
#   'tag': 'Full Stack',
#   'basesalary': 10.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 0.0,
#   'gender': 'male',
#   'company.name': 'eClinicalWorks',
#   'company.icon': 'https://logo.clearbit.com/eclinicalworks.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-25T02:11:00.000Z',
#   'level': '60',
#   'totalyearlycompensation': 200.0,
#   'location': 'Seattle, WA',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 117.0,
#   'stockgrantvalue': 33.0,
#   'bonus': 50.0,
#   'gender': 'male',
#   'company.name': 'Microsoft',
#   'company.icon': 'https://logo.clearbit.com/microsoft.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-25T01:55:29.000Z',
#   'level': 'IC-6',
#   'totalyearlycompensation': 730.0,
#   'location': 'Reston, VA',
#   'yearsofexperience': 12.0,
#   'yearsatcompany': 5.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 230.0,
#   'stockgrantvalue': 500.0,
#   'bonus': 0.0,
#   'gender': None,
#   'company.name': 'Oracle',
#   'company.icon': 'https://logo.clearbit.com/oracle.com',
#   'company.registered': True,
#   'Remote': 'yes',
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-25T01:52:06.000Z',
#   'level': 'P4',
#   'totalyearlycompensation': 140.0,
#   'location': 'Weston, FL',
#   'yearsofexperience': 15.0,
#   'yearsatcompany': 7.0,
#   'tag': 'Full Stack',
#   'basesalary': 135.0,
#   'stockgrantvalue': 5.0,
#   'bonus': 0.0,
#   'gender': 'male',
#   'company.name': 'UKG',
#   'company.icon': 'https://logo.clearbit.com/ukg.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Doctorate (PhD)',
#   'Race': 'Hispanic / Latino'},
#  {'timestamp': '2021-10-25T01:34:02.000Z',
#   'level': 'L4',
#   'totalyearlycompensation': 224.0,
#   'location': 'San Francisco, CA',
#   'yearsofexperience': 4.0,
#   'yearsatcompany': 2.0,
#   'tag': 'Android',
#   'basesalary': 146.0,
#   'stockgrantvalue': 66.0,
#   'bonus': 12.0,
#   'gender': 'male',
#   'company.name': 'Uber',
#   'company.icon': 'https://logo.clearbit.com/uber.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Hispanic / Latino'},
#  {'timestamp': '2021-10-25T00:30:03.000Z',
#   'level': 'Software Engineer (SWE)',
#   'totalyearlycompensation': 183.0,
#   'location': 'San Francisco, CA',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'API Development (Back-End)',
#   'basesalary': 136.0,
#   'stockgrantvalue': 33.0,
#   'bonus': 14.0,
#   'gender': None,
#   'company.name': 'Twitter',
#   'company.icon': 'https://logo.clearbit.com/twitter.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-25T00:19:09.000Z',
#   'level': 'E5',
#   'totalyearlycompensation': 415.0,
#   'location': 'Menlo Park, CA',
#   'yearsofexperience': 20.0,
#   'yearsatcompany': 6.0,
#   'tag': 'Testing (SDET)',
#   'basesalary': 200.0,
#   'stockgrantvalue': 200.0,
#   'bonus': 15.0,
#   'gender': 'male',
#   'company.name': 'Facebook',
#   'company.icon': 'https://logo.clearbit.com/facebook.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'White'},
#  {'timestamp': '2021-10-25T00:18:31.000Z',
#   'level': 'Senior Software Engineer',
#   'totalyearlycompensation': 333.0,
#   'location': 'Sunnyvale, CA',
#   'yearsofexperience': 6.0,
#   'yearsatcompany': 2.0,
#   'tag': 'API Development (Back-End)',
#   'basesalary': 176.0,
#   'stockgrantvalue': 140.0,
#   'bonus': 17.0,
#   'gender': None,
#   'company.name': 'LinkedIn',
#   'company.icon': 'https://logo.clearbit.com/linkedin.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-25T00:16:56.000Z',
#   'level': 'Intermediate',
#   'totalyearlycompensation': 87.0,
#   'location': 'Toronto, ON, Canada',
#   'yearsofexperience': 1.0,
#   'yearsatcompany': 0.0,
#   'tag': 'ML / AI',
#   'basesalary': 81.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 6.0,
#   'gender': None,
#   'company.name': 'Thomson Reuters',
#   'company.icon': 'https://logo.clearbit.com/thomsonreuters.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-25T00:15:49.000Z',
#   'level': 'Software Developer',
#   'totalyearlycompensation': 69.0,
#   'location': 'Winnipeg, MB, Canada',
#   'yearsofexperience': 2.0,
#   'yearsatcompany': 0.0,
#   'tag': 'API Development (Back-End)',
#   'basesalary': 61.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 8.0,
#   'gender': 'male',
#   'company.name': 'Priceline',
#   'company.icon': None,
#   'company.registered': False,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-25T00:11:17.000Z',
#   'level': 'L4',
#   'totalyearlycompensation': 340.0,
#   'location': 'Mountain View, CA',
#   'yearsofexperience': 6.0,
#   'yearsatcompany': 1.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 162.0,
#   'stockgrantvalue': 162.0,
#   'bonus': 16.0,
#   'gender': 'male',
#   'company.name': 'Google',
#   'company.icon': 'https://logo.clearbit.com/google.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-25T00:01:16.000Z',
#   'level': 'Associate',
#   'totalyearlycompensation': 160.0,
#   'location': 'New York, NY',
#   'yearsofexperience': 2.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Full Stack',
#   'basesalary': 140.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 20.0,
#   'gender': None,
#   'company.name': 'JPMorgan Chase',
#   'company.icon': 'https://logo.clearbit.com/jpmorganchase.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T23:53:55.000Z',
#   'level': 'E5',
#   'totalyearlycompensation': 411.0,
#   'location': 'Menlo Park, CA',
#   'yearsofexperience': 8.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Android',
#   'basesalary': 205.0,
#   'stockgrantvalue': 175.0,
#   'bonus': 31.0,
#   'gender': None,
#   'company.name': 'Facebook',
#   'company.icon': 'https://logo.clearbit.com/facebook.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T23:53:02.000Z',
#   'level': 'L5',
#   'totalyearlycompensation': 241.0,
#   'location': 'Seattle, WA',
#   'yearsofexperience': 5.0,
#   'yearsatcompany': 5.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 151.0,
#   'stockgrantvalue': 90.0,
#   'bonus': 0.0,
#   'gender': None,
#   'company.name': 'Amaz',
#   'company.icon': None,
#   'company.registered': False,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': None},
#  {'timestamp': '2021-10-24T23:50:02.000Z',
#   'level': 'Senior',
#   'totalyearlycompensation': 130.0,
#   'location': 'Toronto, ON, Canada',
#   'yearsofexperience': 4.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Full Stack',
#   'basesalary': 130.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 0.0,
#   'gender': None,
#   'company.name': 'Wealthsimple',
#   'company.icon': None,
#   'company.registered': False,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T23:38:34.000Z',
#   'level': 'L5',
#   'totalyearlycompensation': 600.0,
#   'location': 'Los Gatos, CA',
#   'yearsofexperience': 16.0,
#   'yearsatcompany': 2.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 600.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 0.0,
#   'gender': None,
#   'company.name': 'Netflix',
#   'company.icon': 'https://logo.clearbit.com/netflix.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T23:27:54.000Z',
#   'level': 'Team Lead',
#   'totalyearlycompensation': 175.0,
#   'location': 'Seattle, WA',
#   'yearsofexperience': 10.0,
#   'yearsatcompany': 4.0,
#   'tag': 'Full Stack',
#   'basesalary': 163.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 12.0,
#   'gender': None,
#   'company.name': 'CBRE',
#   'company.icon': 'https://logo.clearbit.com/cbre.us',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T23:21:55.000Z',
#   'level': 'IC1',
#   'totalyearlycompensation': 152.0,
#   'location': 'San Francisco, CA',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Full Stack',
#   'basesalary': 118.0,
#   'stockgrantvalue': 28.0,
#   'bonus': 6.0,
#   'gender': None,
#   'company.name': 'Cloudera',
#   'company.icon': 'https://logo.clearbit.com/cloudera.com',
#   'company.registered': True,
#   'Remote': 'yes',
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T23:19:56.000Z',
#   'level': 'Engineering Analyst',
#   'totalyearlycompensation': 85.0,
#   'location': 'Chandler, AZ',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Full Stack',
#   'basesalary': 75.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 10.0,
#   'gender': None,
#   'company.name': 'Wells Fargo',
#   'company.icon': 'https://logo.clearbit.com/wellsfargo.com',
#   'company.registered': True,
#   'Remote': 'yes',
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T23:00:05.000Z',
#   'level': 'SDE II',
#   'totalyearlycompensation': 240.0,
#   'location': 'Seattle, WA',
#   'yearsofexperience': 4.0,
#   'yearsatcompany': 4.0,
#   'tag': 'API Development (Back-End)',
#   'basesalary': 140.0,
#   'stockgrantvalue': 100.0,
#   'bonus': 0.0,
#   'gender': 'male',
#   'company.name': 'Amazon',
#   'company.icon': 'https://logo.clearbit.com/amazon.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'White'},
#  {'timestamp': '2021-10-24T22:26:21.000Z',
#   'level': 'L5',
#   'totalyearlycompensation': 60.0,
#   'location': 'Kiev, KC, Ukraine',
#   'yearsofexperience': 10.0,
#   'yearsatcompany': 1.0,
#   'tag': 'Testing (SDET)',
#   'basesalary': 60.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 0.0,
#   'gender': 'male',
#   'company.name': 'GlobalLogic',
#   'company.icon': 'https://logo.clearbit.com/globallogic.com',
#   'company.registered': True,
#   'Remote': 'yes',
#   'Academic Level': 'Master',
#   'Race': 'White'},
#  {'timestamp': '2021-10-24T21:40:43.000Z',
#   'level': 'L4',
#   'totalyearlycompensation': 193.0,
#   'location': 'San Francisco, CA',
#   'yearsofexperience': 1.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 145.0,
#   'stockgrantvalue': 38.0,
#   'bonus': 11.0,
#   'gender': 'female',
#   'company.name': 'Amazon',
#   'company.icon': 'https://logo.clearbit.com/amazon.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T21:39:40.000Z',
#   'level': 'L3',
#   'totalyearlycompensation': 166.0,
#   'location': 'Portland, OR',
#   'yearsofexperience': 5.0,
#   'yearsatcompany': 2.0,
#   'tag': 'Web Development (Front-End)',
#   'basesalary': 144.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 22.0,
#   'gender': 'male',
#   'company.name': 'Nike',
#   'company.icon': 'https://logo.clearbit.com/nike.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'White'},
#  {'timestamp': '2021-10-24T21:24:26.000Z',
#   'level': 'Technical Leader 1',
#   'totalyearlycompensation': 168.0,
#   'location': 'Raleigh, NC',
#   'yearsofexperience': 14.0,
#   'yearsatcompany': 11.0,
#   'tag': 'Networking',
#   'basesalary': 148.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 20.0,
#   'gender': 'male',
#   'company.name': 'Cisco',
#   'company.icon': 'https://logo.clearbit.com/cisco.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T21:23:34.000Z',
#   'level': 'L4',
#   'totalyearlycompensation': 250.0,
#   'location': 'New York, NY',
#   'yearsofexperience': 5.0,
#   'yearsatcompany': 3.0,
#   'tag': 'Full Stack',
#   'basesalary': 155.0,
#   'stockgrantvalue': 60.0,
#   'bonus': 35.0,
#   'gender': 'male',
#   'company.name': 'Google',
#   'company.icon': 'https://logo.clearbit.com/google.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': None},
#  {'timestamp': '2021-10-24T21:05:14.000Z',
#   'level': '17',
#   'totalyearlycompensation': 177.0,
#   'location': 'Seattle, WA',
#   'yearsofexperience': 16.0,
#   'yearsatcompany': 6.0,
#   'tag': 'DevOps',
#   'basesalary': 162.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 15.0,
#   'gender': 'male',
#   'company.name': 'Nordstrom',
#   'company.icon': 'https://logo.clearbit.com/nordstrom.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T20:32:02.000Z',
#   'level': '59',
#   'totalyearlycompensation': 130.0,
#   'location': 'Atlanta, GA',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 95.0,
#   'stockgrantvalue': 30.0,
#   'bonus': 5.0,
#   'gender': 'male',
#   'company.name': 'Microsoft',
#   'company.icon': 'https://logo.clearbit.com/microsoft.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T20:29:34.000Z',
#   'level': 'L6',
#   'totalyearlycompensation': 310.0,
#   'location': 'Seattle, WA',
#   'yearsofexperience': 4.0,
#   'yearsatcompany': 4.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 160.0,
#   'stockgrantvalue': 150.0,
#   'bonus': 0.0,
#   'gender': None,
#   'company.name': 'Amazon',
#   'company.icon': 'https://logo.clearbit.com/amazon.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T20:13:16.000Z',
#   'level': 'Senior',
#   'totalyearlycompensation': 122.0,
#   'location': 'Vancouver, BC, Canada',
#   'yearsofexperience': 5.0,
#   'yearsatcompany': 1.0,
#   'tag': 'API Development (Back-End)',
#   'basesalary': 105.0,
#   'stockgrantvalue': 6.0,
#   'bonus': 11.0,
#   'gender': None,
#   'company.name': 'Treasure Data',
#   'company.icon': 'https://logo.clearbit.com/treasuredata.com',
#   'company.registered': True,
#   'Remote': 'yes',
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T19:33:41.000Z',
#   'level': 'L2',
#   'totalyearlycompensation': 135.0,
#   'location': 'Fort Lauderdale, FL',
#   'yearsofexperience': 2.0,
#   'yearsatcompany': 1.0,
#   'tag': 'Web Development (Front-End)',
#   'basesalary': 123.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 12.0,
#   'gender': 'male',
#   'company.name': 'Juniper',
#   'company.icon': None,
#   'company.registered': False,
#   'Remote': 'yes',
#   'Academic Level': 'Bachelor',
#   'Race': 'White'},
#  {'timestamp': '2021-10-24T19:10:20.000Z',
#   'level': 'IC3',
#   'totalyearlycompensation': 197.0,
#   'location': 'San Francisco, CA',
#   'yearsofexperience': 2.0,
#   'yearsatcompany': 2.0,
#   'tag': 'Full Stack',
#   'basesalary': 145.0,
#   'stockgrantvalue': 52.0,
#   'bonus': 0.0,
#   'gender': 'male',
#   'company.name': 'yelp',
#   'company.icon': 'https://logo.clearbit.com/yelp.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T18:46:37.000Z',
#   'level': 'Senior Engineer',
#   'totalyearlycompensation': 160.0,
#   'location': 'San Jose, CA',
#   'yearsofexperience': 5.0,
#   'yearsatcompany': 5.0,
#   'tag': 'Networking',
#   'basesalary': 132.0,
#   'stockgrantvalue': 16.0,
#   'bonus': 12.0,
#   'gender': None,
#   'company.name': 'Qualcomm',
#   'company.icon': 'https://logo.clearbit.com/qualcomm.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T18:38:24.000Z',
#   'level': 'L6',
#   'totalyearlycompensation': 320.0,
#   'location': 'Seattle, WA',
#   'yearsofexperience': 11.0,
#   'yearsatcompany': 6.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 160.0,
#   'stockgrantvalue': 160.0,
#   'bonus': 0.0,
#   'gender': None,
#   'company.name': 'Amazon',
#   'company.icon': 'https://logo.clearbit.com/amazon.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T18:38:05.000Z',
#   'level': 'Systems Architect',
#   'totalyearlycompensation': 116.0,
#   'location': 'Cary, NC',
#   'yearsofexperience': 4.0,
#   'yearsatcompany': 4.0,
#   'tag': 'API Development (Back-End)',
#   'basesalary': 105.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 11.0,
#   'gender': 'male',
#   'company.name': 'SAS Software',
#   'company.icon': 'https://logo.clearbit.com/sas.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'White'},
#  {'timestamp': '2021-10-24T18:32:34.000Z',
#   'level': 'L8',
#   'totalyearlycompensation': 187.0,
#   'location': 'Austin, TX',
#   'yearsofexperience': 11.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 165.0,
#   'stockgrantvalue': 10.0,
#   'bonus': 12.0,
#   'gender': 'male',
#   'company.name': 'Dell Technologies',
#   'company.icon': 'https://i.imgur.com/Q4gKiVL.png',
#   'company.registered': True,
#   'Remote': 'yes',
#   'Academic Level': 'Bachelor',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T18:18:25.000Z',
#   'level': 'L5',
#   'totalyearlycompensation': 145.0,
#   'location': 'Dublin, DN, Ireland',
#   'yearsofexperience': 5.0,
#   'yearsatcompany': 1.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 108.0,
#   'stockgrantvalue': 9.0,
#   'bonus': 28.0,
#   'gender': None,
#   'company.name': 'AWS',
#   'company.icon': None,
#   'company.registered': False,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T18:11:48.000Z',
#   'level': 'Software Engineer',
#   'totalyearlycompensation': 175.0,
#   'location': 'New York, NY',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Production',
#   'basesalary': 153.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 22.0,
#   'gender': 'male',
#   'company.name': 'Bloomberg',
#   'company.icon': 'https://logo.clearbit.com/bloomberg.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T18:09:31.000Z',
#   'level': 'EC2',
#   'totalyearlycompensation': 85.0,
#   'location': 'London, EN, United Kingdom',
#   'yearsofexperience': 1.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Full Stack',
#   'basesalary': 60.0,
#   'stockgrantvalue': 15.0,
#   'bonus': 10.0,
#   'gender': 'male',
#   'company.name': 'Yelp',
#   'company.icon': 'https://logo.clearbit.com/yelp.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': None},
#  {'timestamp': '2021-10-24T17:37:05.000Z',
#   'level': 'Band 8',
#   'totalyearlycompensation': 138.0,
#   'location': 'Boston, MA',
#   'yearsofexperience': 6.0,
#   'yearsatcompany': 6.0,
#   'tag': 'Web Development (Front-End)',
#   'basesalary': 138.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 0.0,
#   'gender': None,
#   'company.name': 'IBM',
#   'company.icon': 'https://logo.clearbit.com/ibm.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T17:12:31.000Z',
#   'level': 'L2',
#   'totalyearlycompensation': 17.0,
#   'location': 'Noida, UP, India',
#   'yearsofexperience': 3.0,
#   'yearsatcompany': 3.0,
#   'tag': 'Project Lead',
#   'basesalary': 14.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 3.0,
#   'gender': 'male',
#   'company.name': 'Samsung',
#   'company.icon': 'https://logo.clearbit.com/samsung.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T16:58:26.000Z',
#   'level': '66',
#   'totalyearlycompensation': 440.0,
#   'location': 'Bend, OR',
#   'yearsofexperience': 16.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Web Development (Front-End)',
#   'basesalary': 205.0,
#   'stockgrantvalue': 125.0,
#   'bonus': 110.0,
#   'gender': 'male',
#   'company.name': 'Microsoft',
#   'company.icon': 'https://logo.clearbit.com/microsoft.com',
#   'company.registered': True,
#   'Remote': 'yes',
#   'Academic Level': 'Bachelor',
#   'Race': 'White'},
#  {'timestamp': '2021-10-24T16:33:44.000Z',
#   'level': 'C6',
#   'totalyearlycompensation': 76.0,
#   'location': 'Helsinki, ES, Finland',
#   'yearsofexperience': 3.0,
#   'yearsatcompany': 0.0,
#   'tag': 'API Development (Back-End)',
#   'basesalary': 75.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 1.0,
#   'gender': 'male',
#   'company.name': 'Zalando',
#   'company.icon': 'https://logo.clearbit.com/zalando.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T16:30:47.000Z',
#   'level': 'Software Engineer 1',
#   'totalyearlycompensation': 146.0,
#   'location': 'San Diego, CA',
#   'yearsofexperience': 4.0,
#   'yearsatcompany': 3.0,
#   'tag': 'Full Stack',
#   'basesalary': 115.0,
#   'stockgrantvalue': 19.0,
#   'bonus': 12.0,
#   'gender': 'male',
#   'company.name': 'Intuit',
#   'company.icon': 'https://logo.clearbit.com/intuit.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T16:22:04.000Z',
#   'level': 'Software Engineer II',
#   'totalyearlycompensation': 143.0,
#   'location': 'Chicago, IL',
#   'yearsofexperience': 2.0,
#   'yearsatcompany': 1.0,
#   'tag': 'Full Stack',
#   'basesalary': 130.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 13.0,
#   'gender': 'male',
#   'company.name': 'PEAK6',
#   'company.icon': 'https://logo.clearbit.com/peak6.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': None},
#  {'timestamp': '2021-10-24T16:11:41.000Z',
#   'level': 'Engineer',
#   'totalyearlycompensation': 138.0,
#   'location': 'Overland Park, KS',
#   'yearsofexperience': 4.0,
#   'yearsatcompany': 0.0,
#   'tag': 'DevOps',
#   'basesalary': 116.0,
#   'stockgrantvalue': 10.0,
#   'bonus': 12.0,
#   'gender': 'male',
#   'company.name': 'T-Mobile',
#   'company.icon': 'https://logo.clearbit.com/t-mobile.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'White'},
#  {'timestamp': '2021-10-24T15:20:55.000Z',
#   'level': 'L6',
#   'totalyearlycompensation': 423.0,
#   'location': 'Sunnyvale, CA',
#   'yearsofexperience': 13.0,
#   'yearsatcompany': 10.0,
#   'tag': 'Android',
#   'basesalary': 185.0,
#   'stockgrantvalue': 238.0,
#   'bonus': 0.0,
#   'gender': 'male',
#   'company.name': 'Amazon',
#   'company.icon': 'https://logo.clearbit.com/amazon.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T14:26:03.000Z',
#   'level': 'Senior Software Engineer',
#   'totalyearlycompensation': 223.0,
#   'location': 'New York, NY',
#   'yearsofexperience': 20.0,
#   'yearsatcompany': 6.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 189.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 34.0,
#   'gender': 'male',
#   'company.name': 'Bloomberg',
#   'company.icon': 'https://logo.clearbit.com/bloomberg.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': 'White'},
#  {'timestamp': '2021-10-24T14:02:26.000Z',
#   'level': 'L3',
#   'totalyearlycompensation': 165.0,
#   'location': 'Seattle, WA',
#   'yearsofexperience': 1.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 120.0,
#   'stockgrantvalue': 5.0,
#   'bonus': 40.0,
#   'gender': 'male',
#   'company.name': 'Amazon',
#   'company.icon': 'https://logo.clearbit.com/amazon.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Two or More Races'},
#  {'timestamp': '2021-10-24T13:34:28.000Z',
#   'level': 'L3',
#   'totalyearlycompensation': 225.0,
#   'location': 'Boston, MA',
#   'yearsofexperience': 7.0,
#   'yearsatcompany': 2.0,
#   'tag': 'Full Stack',
#   'basesalary': 151.0,
#   'stockgrantvalue': 59.0,
#   'bonus': 15.0,
#   'gender': 'male',
#   'company.name': 'Wayfair',
#   'company.icon': 'https://logo.clearbit.com/wayfair.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': None},
#  {'timestamp': '2021-10-24T13:05:01.000Z',
#   'level': '63',
#   'totalyearlycompensation': 70.0,
#   'location': 'Hyderabad, TS, India',
#   'yearsofexperience': 10.0,
#   'yearsatcompany': 6.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 48.0,
#   'stockgrantvalue': 17.0,
#   'bonus': 5.0,
#   'gender': 'male',
#   'company.name': 'Microsoft',
#   'company.icon': 'https://logo.clearbit.com/microsoft.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T12:59:42.000Z',
#   'level': '65',
#   'totalyearlycompensation': 468.0,
#   'location': 'Redmond, WA',
#   'yearsofexperience': 13.0,
#   'yearsatcompany': 10.0,
#   'tag': 'ML / AI',
#   'basesalary': 205.0,
#   'stockgrantvalue': 200.0,
#   'bonus': 63.0,
#   'gender': 'male',
#   'company.name': 'Microsoft',
#   'company.icon': 'https://logo.clearbit.com/microsoft.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T11:51:32.000Z',
#   'level': 'G17',
#   'totalyearlycompensation': 64.0,
#   'location': 'Saint Petersburg, SP, Russia',
#   'yearsofexperience': 9.0,
#   'yearsatcompany': 4.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 37.0,
#   'stockgrantvalue': 22.0,
#   'bonus': 5.0,
#   'gender': 'male',
#   'company.name': 'Yandex',
#   'company.icon': 'https://logo.clearbit.com/yandex.ru',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'White'},
#  {'timestamp': '2021-10-24T10:44:13.000Z',
#   'level': 'CL2',
#   'totalyearlycompensation': 15.0,
#   'location': 'Noida, UP, India',
#   'yearsofexperience': 3.0,
#   'yearsatcompany': 3.0,
#   'tag': 'ML / AI',
#   'basesalary': 12.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 3.0,
#   'gender': 'male',
#   'company.name': 'Samsung',
#   'company.icon': 'https://logo.clearbit.com/samsung.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': None},
#  {'timestamp': '2021-10-24T09:11:19.000Z',
#   'level': 'G10',
#   'totalyearlycompensation': 275.0,
#   'location': 'San Francisco, CA',
#   'yearsofexperience': 6.0,
#   'yearsatcompany': 6.0,
#   'tag': 'Networking',
#   'basesalary': 185.0,
#   'stockgrantvalue': 65.0,
#   'bonus': 25.0,
#   'gender': 'male',
#   'company.name': 'Cisco',
#   'company.icon': 'https://logo.clearbit.com/cisco.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T09:03:47.000Z',
#   'level': 'L8',
#   'totalyearlycompensation': 360.0,
#   'location': 'San Francisco, CA',
#   'yearsofexperience': 7.0,
#   'yearsatcompany': 2.0,
#   'tag': 'Full Stack',
#   'basesalary': 200.0,
#   'stockgrantvalue': 130.0,
#   'bonus': 30.0,
#   'gender': 'male',
#   'company.name': 'Airbnb',
#   'company.icon': 'https://logo.clearbit.com/airbnb.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T08:57:57.000Z',
#   'level': '60',
#   'totalyearlycompensation': 181.0,
#   'location': 'Seattle, WA',
#   'yearsofexperience': 2.0,
#   'yearsatcompany': 2.0,
#   'tag': 'API Development (Back-End)',
#   'basesalary': 131.0,
#   'stockgrantvalue': 25.0,
#   'bonus': 25.0,
#   'gender': 'male',
#   'company.name': 'Microsoft',
#   'company.icon': 'https://logo.clearbit.com/microsoft.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T08:49:34.000Z',
#   'level': '61',
#   'totalyearlycompensation': 203.0,
#   'location': 'Redmond, WA',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 133.0,
#   'stockgrantvalue': 50.0,
#   'bonus': 20.0,
#   'gender': 'male',
#   'company.name': 'Microsoft',
#   'company.icon': 'https://logo.clearbit.com/microsoft.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Doctorate (PhD)',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T08:00:17.000Z',
#   'level': 'L3',
#   'totalyearlycompensation': 40.0,
#   'location': 'Bangalore, KA, India',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 23.0,
#   'stockgrantvalue': 9.0,
#   'bonus': 8.0,
#   'gender': None,
#   'company.name': 'Airbnb',
#   'company.icon': 'https://logo.clearbit.com/airbnb.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T07:30:39.000Z',
#   'level': 'l2',
#   'totalyearlycompensation': 16.0,
#   'location': 'Bangalore, KA, India',
#   'yearsofexperience': 3.0,
#   'yearsatcompany': 3.0,
#   'tag': 'Networking',
#   'basesalary': 14.0,
#   'stockgrantvalue': 1.0,
#   'bonus': 1.0,
#   'gender': 'male',
#   'company.name': 'Juniper Networks',
#   'company.icon': 'https://logo.clearbit.com/juniper.net',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T07:18:16.000Z',
#   'level': 'Distinguished Engineer',
#   'totalyearlycompensation': 900.0,
#   'location': 'San Jose, CA',
#   'yearsofexperience': 22.0,
#   'yearsatcompany': 22.0,
#   'tag': 'Networking',
#   'basesalary': 290.0,
#   'stockgrantvalue': 450.0,
#   'bonus': 160.0,
#   'gender': 'male',
#   'company.name': 'Cisco',
#   'company.icon': 'https://logo.clearbit.com/cisco.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T07:11:05.000Z',
#   'level': 'SEIII',
#   'totalyearlycompensation': 249.0,
#   'location': 'Boston, MA',
#   'yearsofexperience': 6.0,
#   'yearsatcompany': 2.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 159.0,
#   'stockgrantvalue': 75.0,
#   'bonus': 15.0,
#   'gender': None,
#   'company.name': 'Chewy',
#   'company.icon': 'https://logo.clearbit.com/chewy.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T06:56:17.000Z',
#   'level': 'P2',
#   'totalyearlycompensation': 195.0,
#   'location': 'San Francisco, CA',
#   'yearsofexperience': 5.0,
#   'yearsatcompany': 1.0,
#   'tag': 'API Development (Back-End)',
#   'basesalary': 150.0,
#   'stockgrantvalue': 25.0,
#   'bonus': 20.0,
#   'gender': 'male',
#   'company.name': 'Turo',
#   'company.icon': 'https://logo.clearbit.com/turo.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T06:43:30.000Z',
#   'level': 'Grade 10',
#   'totalyearlycompensation': 230.0,
#   'location': 'San Jose, CA',
#   'yearsofexperience': 7.0,
#   'yearsatcompany': 5.0,
#   'tag': 'Web Development (Front-End)',
#   'basesalary': 153.0,
#   'stockgrantvalue': 50.0,
#   'bonus': 27.0,
#   'gender': None,
#   'company.name': 'Cisco',
#   'company.icon': 'https://logo.clearbit.com/cisco.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T05:45:02.000Z',
#   'level': 'Senior Software Engineer',
#   'totalyearlycompensation': 1200.0,
#   'location': 'Los Angeles, CA',
#   'yearsofexperience': 8.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Full Stack',
#   'basesalary': 1200.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 0.0,
#   'gender': None,
#   'company.name': 'Netflix',
#   'company.icon': 'https://logo.clearbit.com/netflix.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T05:35:02.000Z',
#   'level': 'L4',
#   'totalyearlycompensation': 175.0,
#   'location': 'Newark, CA',
#   'yearsofexperience': 5.0,
#   'yearsatcompany': 2.0,
#   'tag': 'Android',
#   'basesalary': 140.0,
#   'stockgrantvalue': 35.0,
#   'bonus': 0.0,
#   'gender': None,
#   'company.name': 'Lucid Motors',
#   'company.icon': 'https://logo.clearbit.com/lucidmotors.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T05:32:17.000Z',
#   'level': 'L2',
#   'totalyearlycompensation': 127.0,
#   'location': 'San Diego, CA',
#   'yearsofexperience': 5.0,
#   'yearsatcompany': 2.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 116.0,
#   'stockgrantvalue': 5.0,
#   'bonus': 6.0,
#   'gender': 'male',
#   'company.name': 'Illumina',
#   'company.icon': 'https://logo.clearbit.com/illumina.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T04:59:49.000Z',
#   'level': 'P4',
#   'totalyearlycompensation': 217.0,
#   'location': 'Seattle, WA',
#   'yearsofexperience': 2.0,
#   'yearsatcompany': 0.0,
#   'tag': 'API Development (Back-End)',
#   'basesalary': 145.0,
#   'stockgrantvalue': 58.0,
#   'bonus': 15.0,
#   'gender': 'male',
#   'company.name': 'Atlassian',
#   'company.icon': 'https://logo.clearbit.com/atlassian.com',
#   'company.registered': True,
#   'Remote': 'yes',
#   'Academic Level': 'Bachelor',
#   'Race': 'Hispanic / Latino'},
#  {'timestamp': '2021-10-24T04:49:41.000Z',
#   'level': 'E5',
#   'totalyearlycompensation': 380.0,
#   'location': 'New York, NY',
#   'yearsofexperience': 4.0,
#   'yearsatcompany': 4.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 200.0,
#   'stockgrantvalue': 160.0,
#   'bonus': 20.0,
#   'gender': 'male',
#   'company.name': 'Facebook',
#   'company.icon': 'https://logo.clearbit.com/facebook.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T04:49:03.000Z',
#   'level': 'L4',
#   'totalyearlycompensation': 150.0,
#   'location': 'Seattle, WA',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'API Development (Back-End)',
#   'basesalary': 116.0,
#   'stockgrantvalue': 22.0,
#   'bonus': 13.0,
#   'gender': 'male',
#   'company.name': 'Amazon',
#   'company.icon': 'https://logo.clearbit.com/amazon.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'White'},
#  {'timestamp': '2021-10-24T04:39:52.000Z',
#   'level': 'Associate',
#   'totalyearlycompensation': 150.0,
#   'location': 'New York, NY',
#   'yearsofexperience': 3.0,
#   'yearsatcompany': 3.0,
#   'tag': 'Data',
#   'basesalary': 130.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 20.0,
#   'gender': None,
#   'company.name': 'BlackRock',
#   'company.icon': 'https://logo.clearbit.com/blackrock.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T04:27:42.000Z',
#   'level': 'L3',
#   'totalyearlycompensation': 42.0,
#   'location': 'Jakarta, JK, Indonesia',
#   'yearsofexperience': 6.0,
#   'yearsatcompany': 1.0,
#   'tag': 'Android',
#   'basesalary': 42.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 0.0,
#   'gender': None,
#   'company.name': 'Gojek Tech',
#   'company.icon': 'https://logo.clearbit.com/gojek.io',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T04:06:35.000Z',
#   'level': 'L3',
#   'totalyearlycompensation': 78.0,
#   'location': 'Charlottesville, VA',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Web Development (Front-End)',
#   'basesalary': 78.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 0.0,
#   'gender': 'male',
#   'company.name': 'WillowTree',
#   'company.icon': 'https://logo.clearbit.com/willowtreeapps.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T03:52:59.000Z',
#   'level': 'L6',
#   'totalyearlycompensation': 400.0,
#   'location': 'Mountain View, CA',
#   'yearsofexperience': 11.0,
#   'yearsatcompany': 11.0,
#   'tag': 'Full Stack',
#   'basesalary': 250.0,
#   'stockgrantvalue': 90.0,
#   'bonus': 60.0,
#   'gender': None,
#   'company.name': 'NortonLifeLock',
#   'company.icon': 'https://logo.clearbit.com/nortonlifelock.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-24T03:35:38.000Z',
#   'level': 'Software engineer',
#   'totalyearlycompensation': 25.0,
#   'location': 'Bangalore, KA, India',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Full Stack',
#   'basesalary': 15.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 10.0,
#   'gender': 'male',
#   'company.name': 'Maersk',
#   'company.icon': 'https://logo.clearbit.com/maersk.com',
#   'company.registered': True,
#   'Remote': 'yes',
#   'Academic Level': 'Bachelor',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-24T02:08:57.000Z',
#   'level': 'N/A',
#   'totalyearlycompensation': 375.0,
#   'location': 'New York, NY',
#   'yearsofexperience': 5.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 175.0,
# ...
#   'basesalary': 140.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 46.0,
#   'gender': 'male',
#   'company.name': 'Goldman Sachs',
#   'company.icon': 'https://logo.clearbit.com/goldmansachs.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-14T19:06:36.000Z',
#   'level': 'L4',
#   'totalyearlycompensation': 415.0,
#   'location': 'San Francisco, CA',
#   'yearsofexperience': 4.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 172.0,
#   'stockgrantvalue': 222.0,
#   'bonus': 22.0,
#   'gender': 'male',
#   'company.name': 'Databricks',
#   'company.icon': 'https://logo.clearbit.com/databricks.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-14T18:57:35.000Z',
#   'level': '60',
#   'totalyearlycompensation': 171.0,
#   'location': 'Redmond, WA',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 121.0,
#   'stockgrantvalue': 38.0,
#   'bonus': 12.0,
#   'gender': 'male',
#   'company.name': 'Microsoft',
#   'company.icon': 'https://logo.clearbit.com/microsoft.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-14T18:50:33.000Z',
#   'level': 'Software Engineer 2',
#   'totalyearlycompensation': 151.0,
#   'location': 'Austin, TX',
#   'yearsofexperience': 2.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Android',
#   'basesalary': 125.0,
#   'stockgrantvalue': 20.0,
#   'bonus': 6.0,
#   'gender': 'male',
#   'company.name': 'GoodRx',
#   'company.icon': 'https://logo.clearbit.com/goodrx.com',
#   'company.registered': True,
#   'Remote': 'yes',
#   'Academic Level': 'Bachelor',
#   'Race': 'White'},
#  {'timestamp': '2021-10-14T18:45:41.000Z',
#   'level': 'L4',
#   'totalyearlycompensation': 262.0,
#   'location': 'Sunnyvale, CA',
#   'yearsofexperience': 10.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Site Reliability (SRE)',
#   'basesalary': 175.0,
#   'stockgrantvalue': 61.0,
#   'bonus': 26.0,
#   'gender': 'male',
#   'company.name': 'Google',
#   'company.icon': 'https://logo.clearbit.com/google.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-14T18:38:14.000Z',
#   'level': 'Principal Associate',
#   'totalyearlycompensation': 160.0,
#   'location': 'West McLean, VA',
#   'yearsofexperience': 3.0,
#   'yearsatcompany': 3.0,
#   'tag': 'Full Stack',
#   'basesalary': 150.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 10.0,
#   'gender': None,
#   'company.name': 'Capital One',
#   'company.icon': 'https://logo.clearbit.com/capitalone.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-14T18:37:57.000Z',
#   'level': 'Member of Technical Staff 1',
#   'totalyearlycompensation': 259.0,
#   'location': 'San Jose, CA',
#   'yearsofexperience': 12.0,
#   'yearsatcompany': 10.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 184.0,
#   'stockgrantvalue': 60.0,
#   'bonus': 15.0,
#   'gender': 'male',
#   'company.name': 'eBay',
#   'company.icon': 'https://logo.clearbit.com/ebay.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-14T18:29:36.000Z',
#   'level': 'L2',
#   'totalyearlycompensation': 258.0,
#   'location': 'New York, NY',
#   'yearsofexperience': 3.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Full Stack',
#   'basesalary': 155.0,
#   'stockgrantvalue': 88.0,
#   'bonus': 16.0,
#   'gender': 'male',
#   'company.name': 'goPuff',
#   'company.icon': 'https://logo.clearbit.com/gopuff.com',
#   'company.registered': True,
#   'Remote': 'yes',
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-14T18:12:49.000Z',
#   'level': 'Software Development Engineer 2',
#   'totalyearlycompensation': 115.0,
#   'location': 'Redlands, CA',
#   'yearsofexperience': 3.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Web Development (Front-End)',
#   'basesalary': 106.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 9.0,
#   'gender': 'male',
#   'company.name': 'Esri',
#   'company.icon': 'https://logo.clearbit.com/esri.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-14T18:04:54.000Z',
#   'level': 'Senior MTS',
#   'totalyearlycompensation': 63.0,
#   'location': 'Bangalore, KA, India',
#   'yearsofexperience': 8.0,
#   'yearsatcompany': 0.0,
#   'tag': 'API Development (Back-End)',
#   'basesalary': 45.0,
#   'stockgrantvalue': 10.0,
#   'bonus': 7.0,
#   'gender': 'male',
#   'company.name': 'VMware',
#   'company.icon': 'https://logo.clearbit.com/vmware.com',
#   'company.registered': True,
#   'Remote': 'yes',
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-14T17:56:24.000Z',
#   'level': 'Principal Engineer',
#   'totalyearlycompensation': 525.0,
#   'location': 'Seattle, WA',
#   'yearsofexperience': 7.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 250.0,
#   'stockgrantvalue': 275.0,
#   'bonus': 0.0,
#   'gender': None,
#   'company.name': 'Twilio',
#   'company.icon': 'https://logo.clearbit.com/twilio.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-14T17:52:18.000Z',
#   'level': 'L3',
#   'totalyearlycompensation': 82.0,
#   'location': 'Durham, NC',
#   'yearsofexperience': 12.0,
#   'yearsatcompany': 4.0,
#   'tag': 'Production',
#   'basesalary': 80.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 2.0,
#   'gender': None,
#   'company.name': 'Credit Suisse',
#   'company.icon': 'https://logo.clearbit.com/credit-suisse.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-14T17:38:41.000Z',
#   'level': 'E1',
#   'totalyearlycompensation': 137.0,
#   'location': 'Seattle, WA',
#   'yearsofexperience': 1.0,
#   'yearsatcompany': 0.0,
#   'tag': 'API Development (Back-End)',
#   'basesalary': 115.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 22.0,
#   'gender': 'male',
#   'company.name': 'Nordstrom',
#   'company.icon': 'https://logo.clearbit.com/nordstrom.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-14T17:36:27.000Z',
#   'level': 'L3',
#   'totalyearlycompensation': 145.0,
#   'location': 'Washington, DC',
#   'yearsofexperience': 4.0,
#   'yearsatcompany': 1.0,
#   'tag': 'Testing (SDET)',
#   'basesalary': 115.0,
#   'stockgrantvalue': 30.0,
#   'bonus': 0.0,
#   'gender': 'male',
#   'company.name': 'Chainlink Labs',
#   'company.icon': 'https://logo.clearbit.com/chainlinklabs.com',
#   'company.registered': True,
#   'Remote': 'yes',
#   'Academic Level': 'Bachelor',
#   'Race': 'White'},
#  {'timestamp': '2021-10-14T17:05:45.000Z',
#   'level': 'SDE I',
#   'totalyearlycompensation': 212.0,
#   'location': 'San Francisco, CA',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Full Stack',
#   'basesalary': 136.0,
#   'stockgrantvalue': 69.0,
#   'bonus': 8.0,
#   'gender': None,
#   'company.name': 'Redfin',
#   'company.icon': 'https://logo.clearbit.com/redfin.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-14T16:43:49.000Z',
#   'level': 'L9',
#   'totalyearlycompensation': 140.0,
#   'location': 'New York, NY',
#   'yearsofexperience': 2.0,
#   'yearsatcompany': 2.0,
#   'tag': 'Web Development (Front-End)',
#   'basesalary': 120.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 20.0,
#   'gender': 'female',
#   'company.name': 'TD bank',
#   'company.icon': 'https://logo.clearbit.com/td.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': None},
#  {'timestamp': '2021-10-14T16:03:47.000Z',
#   'level': 'L3',
#   'totalyearlycompensation': 148.0,
#   'location': 'New York, NY',
#   'yearsofexperience': 5.0,
#   'yearsatcompany': 3.0,
#   'tag': 'Full Stack',
#   'basesalary': 148.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 0.0,
#   'gender': None,
#   'company.name': 'Simon Data',
#   'company.icon': 'https://logo.clearbit.com/simondata.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-14T15:59:58.000Z',
#   'level': 'Consultant',
#   'totalyearlycompensation': 19.0,
#   'location': 'Delhi, DL, India',
#   'yearsofexperience': 6.0,
#   'yearsatcompany': 3.0,
#   'tag': 'Data',
#   'basesalary': 17.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 2.0,
#   'gender': 'female',
#   'company.name': 'Deloitte',
#   'company.icon': 'https://logo.clearbit.com/deloitte.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-14T15:22:23.000Z',
#   'level': 'L5',
#   'totalyearlycompensation': 157.0,
#   'location': 'Toronto, ON, Canada',
#   'yearsofexperience': 7.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 120.0,
#   'stockgrantvalue': 25.0,
#   'bonus': 12.0,
#   'gender': 'male',
#   'company.name': 'Auth0',
#   'company.icon': 'https://logo.clearbit.com/auth0.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'White'},
#  {'timestamp': '2021-10-14T15:21:44.000Z',
#   'level': 'Sr Developer 1',
#   'totalyearlycompensation': 146.0,
#   'location': 'Atlanta, GA',
#   'yearsofexperience': 15.0,
#   'yearsatcompany': 4.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 144.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 2.0,
#   'gender': None,
#   'company.name': 'Applied Systems',
#   'company.icon': 'https://logo.clearbit.com/appliedsystems.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-14T15:02:46.000Z',
#   'level': 'L3',
#   'totalyearlycompensation': 120.0,
#   'location': 'Munich, BY, Germany',
#   'yearsofexperience': 3.0,
#   'yearsatcompany': 3.0,
#   'tag': 'Robotics',
#   'basesalary': 120.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 0.0,
#   'gender': 'male',
#   'company.name': 'Google',
#   'company.icon': 'https://logo.clearbit.com/google.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'White'},
#  {'timestamp': '2021-10-14T14:54:13.000Z',
#   'level': 'L3',
#   'totalyearlycompensation': 130.0,
#   'location': 'San Francisco, CA',
#   'yearsofexperience': 4.0,
#   'yearsatcompany': 4.0,
#   'tag': 'ML / AI',
#   'basesalary': 120.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 10.0,
#   'gender': 'male',
#   'company.name': 'Google',
#   'company.icon': 'https://logo.clearbit.com/google.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'White'},
#  {'timestamp': '2021-10-14T14:47:02.000Z',
#   'level': 'L3',
#   'totalyearlycompensation': 91.0,
#   'location': 'Toronto, ON, Canada',
#   'yearsofexperience': 3.0,
#   'yearsatcompany': 1.0,
#   'tag': 'Full Stack',
#   'basesalary': 71.0,
#   'stockgrantvalue': 10.0,
#   'bonus': 10.0,
#   'gender': 'female',
#   'company.name': 'Zynga',
#   'company.icon': 'https://logo.clearbit.com/zynga.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-14T13:54:37.000Z',
#   'level': 'L1',
#   'totalyearlycompensation': 125.0,
#   'location': 'Ithaca, NY',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'API Development (Back-End)',
#   'basesalary': 100.0,
#   'stockgrantvalue': 20.0,
#   'bonus': 5.0,
#   'gender': None,
#   'company.name': 'Circle',
#   'company.icon': 'https://logo.clearbit.com/circle.com',
#   'company.registered': True,
#   'Remote': 'yes',
#   'Academic Level': 'Bachelor',
#   'Race': None},
#  {'timestamp': '2021-10-14T13:24:45.000Z',
#   'level': 'Senior Associate',
#   'totalyearlycompensation': 130.0,
#   'location': 'Orlando, FL',
#   'yearsofexperience': 2.0,
#   'yearsatcompany': 0.0,
#   'tag': 'ML / AI',
#   'basesalary': 120.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 10.0,
#   'gender': None,
#   'company.name': 'KPMG',
#   'company.icon': 'https://logo.clearbit.com/kpmg.ca',
#   'company.registered': True,
#   'Remote': 'yes',
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-14T12:38:28.000Z',
#   'level': 'Software Engineer',
#   'totalyearlycompensation': 216.0,
#   'location': 'Sunnyvale, CA',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Full Stack',
#   'basesalary': 145.0,
#   'stockgrantvalue': 56.0,
#   'bonus': 15.0,
#   'gender': 'female',
#   'company.name': 'LinkedIn',
#   'company.icon': 'https://logo.clearbit.com/linkedin.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-14T12:29:27.000Z',
#   'level': 'Principal Engineer',
#   'totalyearlycompensation': 169.0,
#   'location': 'Dallas, TX',
#   'yearsofexperience': 11.0,
#   'yearsatcompany': 3.0,
#   'tag': 'Full Stack',
#   'basesalary': 151.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 18.0,
#   'gender': 'male',
#   'company.name': 'CBRE',
#   'company.icon': 'https://logo.clearbit.com/cbre.us',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-14T11:18:17.000Z',
#   'level': 'Software Engineer',
#   'totalyearlycompensation': 115.0,
#   'location': 'San Francisco, CA',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'New Grad',
#   'basesalary': 115.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 0.0,
#   'gender': None,
#   'company.name': 'Ironclad',
#   'company.icon': 'https://logo.clearbit.com/ironcladapp.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': None,
#   'Race': None},
#  {'timestamp': '2021-10-14T10:39:07.000Z',
#   'level': 'MTS 2',
#   'totalyearlycompensation': 179.0,
#   'location': 'Palo Alto, CA',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Distributed Systems (Back-End)',
#   'basesalary': 138.0,
#   'stockgrantvalue': 25.0,
#   'bonus': 16.0,
#   'gender': 'female',
#   'company.name': 'VMware',
#   'company.icon': 'https://logo.clearbit.com/vmware.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': None},
#  {'timestamp': '2021-10-14T10:34:46.000Z',
#   'level': 'Associate Member of Technical Staff',
#   'totalyearlycompensation': 183.0,
#   'location': 'San Francisco, CA',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'Backend',
#   'basesalary': 144.0,
#   'stockgrantvalue': 25.0,
#   'bonus': 14.0,
#   'gender': 'female',
#   'company.name': 'Salesforce',
#   'company.icon': 'https://logo.clearbit.com/salesforce.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': None},
#  {'timestamp': '2021-10-14T10:30:16.000Z',
#   'level': 'L3',
#   'totalyearlycompensation': 130.0,
#   'location': 'Seattle, WA',
#   'yearsofexperience': 0.0,
#   'yearsatcompany': 0.0,
#   'tag': 'N/A',
#   'basesalary': 105.0,
#   'stockgrantvalue': 25.0,
#   'bonus': 0.0,
#   'gender': 'female',
#   'company.name': 'Qualtrics',
#   'company.icon': 'https://logo.clearbit.com/qualtrics.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': None},
#  {'timestamp': '2021-10-14T10:27:16.000Z',
#   'level': '602',
#   'totalyearlycompensation': 115.0,
#   'location': 'London, EN, United Kingdom',
#   'yearsofexperience': 5.0,
#   'yearsatcompany': 0.0,
#   'tag': 'API Development (Back-End)',
#   'basesalary': 105.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 10.0,
#   'gender': 'male',
#   'company.name': 'JPMorgan Chase',
#   'company.icon': 'https://logo.clearbit.com/jpmorganchase.com',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Bachelor',
#   'Race': 'Asian'},
#  {'timestamp': '2021-10-14T07:56:29.000Z',
#   'level': 'AVP',
#   'totalyearlycompensation': 70.0,
#   'location': 'Moscow, MC, Russia',
#   'yearsofexperience': 10.0,
#   'yearsatcompany': 2.0,
#   'tag': 'Web Development (Front-End)',
#   'basesalary': 69.0,
#   'stockgrantvalue': 0.0,
#   'bonus': 1.0,
#   'gender': 'male',
#   'company.name': 'Deutsche Bank',
#   'company.icon': 'https://i.imgur.com/Hi9bPmO.png',
#   'company.registered': True,
#   'Remote': None,
#   'Academic Level': 'Master',
#   'Race': 'White'},
#  ...]

# %%
tess = data[0]

# %%
tess['location'] = 'benga, ka, india'

# %%
import requests

# %%
r = requests.post('http://127.0.0.1:8000/data/', json=tess)

# %%
r.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16412/661903446.py in <module>
# ----> 1 r.json()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# ~\AppData\Local\Programs\Python\Python39\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~\AppData\Local\Programs\Python\Python39\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\AppData\Local\Programs\Python\Python39\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
for i in range(47900):
    tt = requests.get('http://127.0.0.1:8000/')
    if(tt.status_code != 200): print('gg')
